# %%
import torch

# %%
ckpt = torch.load("best_model.pth")

# %%
ckpt['output_layer.weight'].shape
# Out:
# torch.Size([27, 27])

# %%
for row in ckpt['hidden_layer.weight']:
    print("{ ", end="")
    for col in row:
        print(f"{col.item():.4f}, ", end="")
    print(" },", end="")
    print()
# Out:
# { 0.0919, -0.4470, -0.1763, 0.0947, -0.0072, 0.3808, 0.1808, 0.6735, 0.1107, -0.4342, 0.0552, -0.2436, -0.0793, -0.2300, -0.1994, -0.0295, 0.0050, 0.0311,  },
# { -0.3742, 0.0592, -0.5372, -2.3765, -0.6202, -2.6841, -1.7713, 0.0997, -0.6365, 0.4884, 0.0526, -1.3355, -0.0240, -0.2414, 0.2228, -0.3945, -0.1121, -0.2674,  },
# { -1.2574, 0.0499, 0.2799, 0.3313, 1.5894, -1.2376, 1.8033, -0.3316, -0.0967, 1.7557, -0.5701, -0.4622, -0.0464, -0.1073, 0.0940, 0.0941, -0.0305, -0.1514,  },
# { 0.4180, -0.0562, 0.1433, 0.5530, 0.0551, 0.6539, -0.1103, 0.3443, 0.3733, -0.6337, 0.0425, -0.0547, 0.1398, -0.1889, -0.1525, -0.2890, 0.0775, -0.3968,  },
# { -0.4664, -0.0935, -0.7975, 0.4681, -0.9691, -1.3936, 2.1046, -0.0805, -0.2130, -0.7328, -0.9806, -0.0027, -0.2308, -1.2130, -0.0765, -1.0743, 0.0949, -0.7968,  },
# { 0.1435, -1.2012, -0.6644, -1.1867, -1.6861, -0.0475, 0.3663, 0.3166, 0.0304, -4.0191, 0.2994, -0.2281, -0.2274, -0.3279, 0.0493, -0.6072, -0.1270, -0.3103,  },
# ...

# %%
print("{ ", end="")
for row in ckpt['hidden_layer.bias']:
    print(f"{row.item():.4f}, ", end="")
print(" }", end="")
# Out:
# { 0.1890, -0.4105, 0.1640, -0.0304, -1.1735, -0.3108, -0.3422, -0.2656, -0.2941, -0.0501, -0.0205, -0.4559, 0.0169, 0.0796, 0.1576, -0.2864, -0.2594, 0.2660, -0.2657, 0.0401, -0.1621, -0.1174, 0.0096, 0.5977, -0.4139, -0.3831, -0.0748,  }

# %%
for row in ckpt['output_layer.weight']:
    print("{ ", end="")
    for col in row:
        print(f"{col.item():.4f}, ", end="")
    print(" },", end="")
    print()
# Out:
# { 0.2240, -1.3465, -0.4087, 0.1205, 1.8035, 0.2655, -0.9558, -0.0195, 1.4875, 0.3851, 0.1094, 0.2468, 0.4221, 0.5457, 0.0343, -0.5762, -1.4075, 0.4473, -0.3350, 1.1957, -1.2441, 0.4377, 0.2722, -1.9642, 0.0196, 1.4480, 0.3025,  },
# { 0.3289, -0.6075, -0.7599, 0.1910, -0.6427, 1.6006, -0.9496, -0.5287, 0.8720, 0.0135, 0.0279, -0.8907, -0.0149, -0.1492, 0.2950, -0.6106, 0.1511, -0.0592, 0.5037, 0.0604, -0.4566, 0.3629, 0.0607, 0.4826, 0.6968, 0.3199, -0.0489,  },
# { 0.0215, -1.0435, -0.5608, 0.0604, 1.1575, 0.5022, -1.0173, -0.2070, 1.2930, 0.2626, 0.3360, 0.1882, 0.5084, 0.4144, -0.1130, -0.4982, -1.2649, 0.2377, -0.1502, 0.9066, -1.0287, 0.2532, 0.3446, -1.5778, 0.1449, 1.1695, 0.2480,  },
# { -0.1043, 0.1819, -0.0708, -0.1233, 0.0574, 0.1037, 0.0335, -0.0434, -0.2207, -0.0206, 0.3626, 0.0170, -0.0243, 0.0866, 0.0867, -0.1412, 0.0708, 0.0621, -0.0936, 0.2031, -0.0993, 0.0448, -0.2855, -0.2186, -0.0891, -0.0400, -0.0412,  },
# ...

# %%
print("{ ", end="")
for row in ckpt['output_layer.bias']:
    print(f"{row.item():.4f}, ", end="")
print(" }", end="")
# Out:
# { 0.0941, -0.0422, 0.2131, 0.1102, -0.0398, 0.1039, 0.1612, -0.0934, -0.1875, 0.1833, -0.0723, 0.1023, -0.0787, 0.1491, 0.0286, 0.2962, 0.1354, -0.0998, 0.2671, -0.1340, 0.0243, 0.0225, 0.0264, -0.1196, 0.0184, -0.0777, -0.1012,  }
